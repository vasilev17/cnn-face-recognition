# %%
import numpy as np
import os
import cv2
from tqdm import tqdm
from tensorflow.keras import applications
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.datasets import fetch_lfw_people

# Function to load the LFW dataset
def load_lfw_data():
    print("Loading LFW dataset...")
    lfw_people = fetch_lfw_people(min_faces_per_person=70, resize=0.4)
    X = lfw_people.images
    y = lfw_people.target
    target_names = lfw_people.target_names
    return X, y, target_names

# Load dataset
X, y, target_names = load_lfw_data()

# Preprocessing function
def preprocess_face(face_image, model_type="vgg16"):
    face_image = cv2.cvtColor(face_image, cv2.COLOR_BGR2RGB)  # Convert to RGB
    
    if model_type == "vgg16" or model_type == "resnet50":
        # Resize to input size of VGG16 and ResNet (224x224)
        face_image = cv2.resize(face_image, (224, 224))
    
    # Convert to float32 and normalize to [0, 1]
    face_image = np.expand_dims(face_image, axis=0).astype(np.float32) / 255.0
    return face_image

# Function to load VGG16 and ResNet models
def load_models():
    print("Loading VGG16 and ResNet50 models...")
    # Load the VGG16 model from Keras applications
    vgg_model = applications.VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

    # ResNet50 model (pre-trained on ImageNet)
    resnet_model = applications.ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    
    print("Models loaded.")
    return vgg_model, resnet_model

# Function to extract features from each model
def extract_features(model, faces, model_type="vgg16"):
    print(f"Extracting features using {model_type} model...")
    features = []
    for i, face in enumerate(tqdm(faces, desc=f"Extracting {model_type} features", total=len(faces))):
        preprocessed_face = preprocess_face(face, model_type=model_type)
        
        # Extract features using the model
        feature = model.predict(preprocessed_face)
        features.append(feature.flatten())

    print(f"Feature extraction for {model_type} completed.")
    return np.array(features)

# Function to save features locally (to not extract every time)
def save_features(features, model_type):
    file_path = f"{model_type}_features.npy"
    np.save(file_path, features)
    print(f"Features saved to {file_path}")

# Function to load features from disk
def load_features(model_type):
    file_path = f"{model_type}_features.npy"
    if os.path.exists(file_path):
        features = np.load(file_path)
        print(f"Loaded features from {file_path}")
        return features
    else:
        print(f"No cached features found for {model_type}.")
        return None

# Load models
vgg_model, resnet_model = load_models()

# Check if features already exist, and load them if they do
vgg_face_features = load_features("vgg16")
resnet_features = load_features("resnet50")

# If features don't exist, extract and save them
if vgg_face_features is None:
    vgg_face_features = extract_features(vgg_model, X, model_type="vgg16")
    save_features(vgg_face_features, "vgg16")

if resnet_features is None:
    resnet_features = extract_features(resnet_model, X, model_type="resnet50")
    save_features(resnet_features, "resnet50")

# Split the dataset into training and testing sets
print("Splitting the dataset into training and testing sets...")
X_train_vgg, X_test_vgg, y_train_vgg, y_test_vgg = train_test_split(vgg_face_features, y, test_size=0.2, random_state=42)
X_train_resnet, X_test_resnet, y_train_resnet, y_test_resnet = train_test_split(resnet_features, y, test_size=0.2, random_state=42)

# Train a classifier for each model's features
svm_vgg_face = SVC(kernel='linear', probability=True)
svm_resnet = SVC(kernel='linear', probability=True)

# Training progress
def train_svm_with_progress(svm, X_train, y_train, model_name="VGG16"):
    print(f"Training SVM classifier on {model_name} features...")
    # We cannot directly use tqdm with sklearn's SVM, so we display manual progress updates
    n_samples = len(X_train)
    for i in range(0, n_samples, 10):  # Train in chunks to show progress
        end = min(i + 10, n_samples)
        svm.fit(X_train[i:end], y_train[i:end])
        percentage_complete = (end / n_samples) * 100
        print(f"{model_name} training progress: {percentage_complete:.2f}%")
    print(f"SVM classifier trained on {model_name} features.")

# Train SVM on VGG16 features
train_svm_with_progress(svm_vgg_face, X_train_vgg, y_train_vgg, model_name="VGG16")

# Train SVM on ResNet features
train_svm_with_progress(svm_resnet, X_train_resnet, y_train_resnet, model_name="ResNet")

# Predict using SVM classifiers
print("Making predictions on the test set using VGG16 model...")
y_pred_vgg_face = svm_vgg_face.predict(X_test_vgg)

print("Making predictions on the test set using ResNet model...")
y_pred_resnet = svm_resnet.predict(X_test_resnet)

# Evaluate accuracy, precision and recall
def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    return accuracy, precision, recall

# Evaluate each model
print("Evaluating VGG16 model...")
accuracy_vgg, precision_vgg, recall_vgg = evaluate_model(y_test_vgg, y_pred_vgg_face)
print("Evaluating ResNet model...")
accuracy_resnet, precision_resnet, recall_resnet = evaluate_model(y_test_resnet, y_pred_resnet)

# Print the results
print("\nVGG16 Model Performance:")
print(f"Accuracy: {accuracy_vgg:.4f}")
print(f"Precision: {precision_vgg:.4f}")
print(f"Recall: {recall_vgg:.4f}\n")

print("ResNet Model Performance:")
print(f"Accuracy: {accuracy_resnet:.4f}")
print(f"Precision: {precision_resnet:.4f}")
print(f"Recall: {recall_resnet:.4f}\n")
# Out:
# Loading LFW dataset...
# LFW dataset loaded with 7 classes.
# Loading VGG16 and ResNet50 models...
# Models loaded.
# Loaded features from vgg16_features.npy
# Loaded features from resnet50_features.npy
# Splitting the dataset into training and testing sets...
# Training SVM classifier on VGG-Face features...
# VGG-Face training progress: 0.97%
# VGG-Face training progress: 1.94%
# VGG-Face training progress: 2.91%
# VGG-Face training progress: 3.88%
# VGG-Face training progress: 4.85%
# VGG-Face training progress: 5.83%
# VGG-Face training progress: 6.80%
# VGG-Face training progress: 7.77%
# VGG-Face training progress: 8.74%
# VGG-Face training progress: 9.71%
# VGG-Face training progress: 10.68%
# VGG-Face training progress: 11.65%
# VGG-Face training progress: 12.62%
# VGG-Face training progress: 13.59%
# VGG-Face training progress: 14.56%
# VGG-Face training progress: 15.53%
# VGG-Face training progress: 16.50%
# VGG-Face training progress: 17.48%
# VGG-Face training progress: 18.45%
# VGG-Face training progress: 19.42%
# VGG-Face training progress: 20.39%
# VGG-Face training progress: 21.36%
# VGG-Face training progress: 22.33%
# VGG-Face training progress: 23.30%
# VGG-Face training progress: 24.27%
# VGG-Face training progress: 25.24%
# VGG-Face training progress: 26.21%
# VGG-Face training progress: 27.18%
# VGG-Face training progress: 28.16%
# VGG-Face training progress: 29.13%
# VGG-Face training progress: 30.10%
# VGG-Face training progress: 31.07%
# VGG-Face training progress: 32.04%
# VGG-Face training progress: 33.01%
# VGG-Face training progress: 33.98%
# VGG-Face training progress: 34.95%
# VGG-Face training progress: 35.92%
# VGG-Face training progress: 36.89%
# VGG-Face training progress: 37.86%
# VGG-Face training progress: 38.83%
# VGG-Face training progress: 39.81%
# VGG-Face training progress: 40.78%
# VGG-Face training progress: 41.75%
# VGG-Face training progress: 42.72%
# VGG-Face training progress: 43.69%
# VGG-Face training progress: 44.66%
# VGG-Face training progress: 45.63%
# VGG-Face training progress: 46.60%
# VGG-Face training progress: 47.57%
# VGG-Face training progress: 48.54%
# VGG-Face training progress: 49.51%
# VGG-Face training progress: 50.49%
# VGG-Face training progress: 51.46%
# VGG-Face training progress: 52.43%
# VGG-Face training progress: 53.40%
# VGG-Face training progress: 54.37%
# VGG-Face training progress: 55.34%
# VGG-Face training progress: 56.31%
# VGG-Face training progress: 57.28%
# VGG-Face training progress: 58.25%
# VGG-Face training progress: 59.22%
# VGG-Face training progress: 60.19%
# VGG-Face training progress: 61.17%
# VGG-Face training progress: 62.14%
# VGG-Face training progress: 63.11%
# VGG-Face training progress: 64.08%
# VGG-Face training progress: 65.05%
# VGG-Face training progress: 66.02%
# VGG-Face training progress: 66.99%
# VGG-Face training progress: 67.96%
# VGG-Face training progress: 68.93%
# VGG-Face training progress: 69.90%
# VGG-Face training progress: 70.87%
# VGG-Face training progress: 71.84%
# VGG-Face training progress: 72.82%
# VGG-Face training progress: 73.79%
# VGG-Face training progress: 74.76%
# VGG-Face training progress: 75.73%
# VGG-Face training progress: 76.70%
# VGG-Face training progress: 77.67%
# VGG-Face training progress: 78.64%
# VGG-Face training progress: 79.61%
# VGG-Face training progress: 80.58%
# VGG-Face training progress: 81.55%
# VGG-Face training progress: 82.52%
# VGG-Face training progress: 83.50%
# VGG-Face training progress: 84.47%
# VGG-Face training progress: 85.44%
# VGG-Face training progress: 86.41%
# VGG-Face training progress: 87.38%
# VGG-Face training progress: 88.35%
# VGG-Face training progress: 89.32%
# VGG-Face training progress: 90.29%
# VGG-Face training progress: 91.26%
# VGG-Face training progress: 92.23%
# VGG-Face training progress: 93.20%
# VGG-Face training progress: 94.17%
# VGG-Face training progress: 95.15%
# VGG-Face training progress: 96.12%
# VGG-Face training progress: 97.09%
# VGG-Face training progress: 98.06%
# VGG-Face training progress: 99.03%
# VGG-Face training progress: 100.00%
# SVM classifier trained on VGG-Face features.
# Training SVM classifier on ResNet features...
# ResNet training progress: 0.97%
# ResNet training progress: 1.94%
# ResNet training progress: 2.91%
# ResNet training progress: 3.88%
# ResNet training progress: 4.85%
# ResNet training progress: 5.83%
# ResNet training progress: 6.80%
# ResNet training progress: 7.77%
# ResNet training progress: 8.74%
# ResNet training progress: 9.71%
# ResNet training progress: 10.68%
# ResNet training progress: 11.65%
# ResNet training progress: 12.62%
# ResNet training progress: 13.59%
# ResNet training progress: 14.56%
# ResNet training progress: 15.53%
# ResNet training progress: 16.50%
# ResNet training progress: 17.48%
# ResNet training progress: 18.45%
# ResNet training progress: 19.42%
# ResNet training progress: 20.39%
# ResNet training progress: 21.36%
# ResNet training progress: 22.33%
# ResNet training progress: 23.30%
# ResNet training progress: 24.27%
# ResNet training progress: 25.24%
# ResNet training progress: 26.21%
# ResNet training progress: 27.18%
# ResNet training progress: 28.16%
# ResNet training progress: 29.13%
# ResNet training progress: 30.10%
# ResNet training progress: 31.07%
# ResNet training progress: 32.04%
# ResNet training progress: 33.01%
# ResNet training progress: 33.98%
# ResNet training progress: 34.95%
# ResNet training progress: 35.92%
# ResNet training progress: 36.89%
# ResNet training progress: 37.86%
# ResNet training progress: 38.83%
# ResNet training progress: 39.81%
# ResNet training progress: 40.78%
# ResNet training progress: 41.75%
# ResNet training progress: 42.72%
# ResNet training progress: 43.69%
# ResNet training progress: 44.66%
# ResNet training progress: 45.63%
# ResNet training progress: 46.60%
# ResNet training progress: 47.57%
# ResNet training progress: 48.54%
# ResNet training progress: 49.51%
# ResNet training progress: 50.49%
# ResNet training progress: 51.46%
# ResNet training progress: 52.43%
# ResNet training progress: 53.40%
# ResNet training progress: 54.37%
# ResNet training progress: 55.34%
# ResNet training progress: 56.31%
# ResNet training progress: 57.28%
# ResNet training progress: 58.25%
# ResNet training progress: 59.22%
# ResNet training progress: 60.19%
# ResNet training progress: 61.17%
# ResNet training progress: 62.14%
# ResNet training progress: 63.11%
# ResNet training progress: 64.08%
# ResNet training progress: 65.05%
# ResNet training progress: 66.02%
# ResNet training progress: 66.99%
# ResNet training progress: 67.96%
# ResNet training progress: 68.93%
# ResNet training progress: 69.90%
# ResNet training progress: 70.87%
# ResNet training progress: 71.84%
# ResNet training progress: 72.82%
# ResNet training progress: 73.79%
# ResNet training progress: 74.76%
# ResNet training progress: 75.73%
# ResNet training progress: 76.70%
# ResNet training progress: 77.67%
# ResNet training progress: 78.64%
# ResNet training progress: 79.61%
# ResNet training progress: 80.58%
# ResNet training progress: 81.55%
# ResNet training progress: 82.52%
# ResNet training progress: 83.50%
# ResNet training progress: 84.47%
# ResNet training progress: 85.44%
# ResNet training progress: 86.41%
# ResNet training progress: 87.38%
# ResNet training progress: 88.35%
# ResNet training progress: 89.32%
# ResNet training progress: 90.29%
# ResNet training progress: 91.26%
# ResNet training progress: 92.23%
# ResNet training progress: 93.20%
# ResNet training progress: 94.17%
# ResNet training progress: 95.15%
# ResNet training progress: 96.12%
# ResNet training progress: 97.09%
# ResNet training progress: 98.06%
# ResNet training progress: 99.03%
# ResNet training progress: 100.00%
# SVM classifier trained on ResNet features.
# Making predictions on the test set using VGG-Face model...
# Making predictions on the test set using ResNet model...
# Evaluating VGG-Face model...
# Evaluating ResNet model...
#
# VGG-Face Model Performance:
# Accuracy: 0.1473
# Precision: 0.0493
# Recall: 0.1473
#
# ResNet Model Performance:
# Accuracy: 0.1822
# Precision: 0.0332
# Recall: 0.1822
